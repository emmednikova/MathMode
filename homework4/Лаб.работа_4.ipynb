# %% [markdown]
# ## Лабораторная работа №4

# %% [markdown]
# ##### Случайная величина ошибки взвешивания распределена по нормальному закону с нулевым математическим ожиданием и стандартным отклонением 4 грамма. Найти вероятность того, что очередное взвешивание будет проведено с ошибкой, не превышающей по модулю 6 граммов.

# %%
from scipy.stats import norm

mu = 0
sigma = 4
x = 6

dist = norm.cdf(x, loc=mu, scale=sigma) - norm.cdf(-x, loc=mu, scale=sigma)

print("Вероятность ошибки не более 6 граммов:", dist)
# Out:
# Вероятность ошибки не более 6 граммов: 0.8663855974622838

# %% [markdown]
# ##### Автобусы некоторого маршрута идут строго по расписанию и интервалом 5 минут. Составьте функцию плотности случайной величины X – времени ожидании очередного автобуса пассажиром, который наугад подошёл к остановке. Найдите вероятность того, что он будет ждать автобус не более 2 минут.

# %%
# Функция плотности вероятности
def func(x):
    if x < 0:
        return 0
    elif x >= 0 and x < 5:
        return 1
    else:
        return 0

# Расчет вероятности ждать автобус не более 2 минут
prob = np.trapz([func(x) for x in np.arange(0, 2.1, 0.1)], dx=0.1)
print("Вероятность ждать автобус не более 2 минут:", prob)
# Out:
# Вероятность ждать автобус не более 2 минут: 2.0000000000000004

# %% [markdown]
# ##### Рост мальчиков возрастной группы 15 лет есть нормально распределённая случайная величина X с математическим ожиданием роста 161 см и среднеквадратичным отклонением 4 см. Какую долю костюмов для мальчиков, имеющих рост от 152 до 158 см, нужно предусмотреть в объёме производства для данной возрастной группы?

# %%
from scipy.stats import norm

# Заданные параметры
mu = 161
sigma = 4

# Расчет доли костюмов для мальчиков с ростом от 152 до 158 см
p = norm.cdf(158, mu, sigma) - norm.cdf(152, mu, sigma)

print(p)
# Out:
# 0.2144028797218235

# %% [markdown]
# ##### На машиностроительном заводе в процессе производства за неделю обнаруживается в среднем 100 бракованных деталей со среднеквадричным отклонением в 12 деталей. Рассчитайте следующее: 1) вероятность того, что за неделю будет 20-30 бракованных деталей, 2) вероятность того, что за день будет хотя бы одна забракованная деталь.

# %%
mean = 100
std = 12

# вероятность того, что за неделю будет 20-30 бракованных деталей
prob_20_30 = norm.cdf(30, mean, std) - norm.cdf(20, mean, std)

# вероятность того, что за день будет хотя бы одна забракованная деталь
prob_one = 1 - norm.cdf(0, mean, std)

print("Вероятность того, что за неделю будет 20-30 бракованных деталей:", prob_20_30)
print("Вероятность того, что за день будет хотя бы одна забракованная деталь:", prob_one)
# Out:
# Вероятность того, что за неделю будет 20-30 бракованных деталей: 2.7034598124020633e-09
# Вероятность того, что за день будет хотя бы одна забракованная деталь: 1.0

# %% [markdown]
# ##### Для всех предыдущих задач вычислите среднее, дисперсию и 0.25 и 0.9 квантили. Для всех предыдущих задач постройте графики cdf и pdf.

# %% [markdown]
# Для 1 задачи

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 0
sigma = 4
x = np.linspace(mu - 6*sigma, mu + 6*sigma, 1000)
pdf = stats.norm.pdf(x, mu, sigma)
cdf = stats.norm.cdf(x, mu, sigma)

# Зададим функцию нормального распределения
normal = norm(0, 4)

# Посчитаем среднее и дисперсию
mean, var = normal.stats(moments='mv')

# Выведем значения среднего и дисперсии
print("Среднее: ", mean)
print("Дисперсия: ", var)

# Посчитаем 0.25 квантиль 
a = normal.ppf(0.25)

# Посчитаем 0.9 квантиль 
b = normal.ppf(0.9)

# Выведем значения квантелей
print("0.25 квантиль: ", a)
print("0.9 квантиль: ", b)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(x, pdf, color='b', label='PDF')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('PDF')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(x, cdf, color='r', label='CDF')
plt.xlabel('x')
plt.ylabel('F(x)')
plt.title('CDF')
plt.legend()

plt.show()
# Out:
# Среднее:  0.0
# Дисперсия:  16.0
# Первый квантиль:  -2.697959000784327
# Второй квантиль:  5.1262062621784015

# %% [markdown]
# Для 2 задачи

# %%
from scipy.stats import expon

# Зададим функцию нормального распределения
normal2 = norm(5, 5)

# Расчет среднего и дисперсии
mean2, var2 = normal2.stats(moments='mv')
print("Среднее:", mean2)
print("Дисперсия:", var2)

# Расчет квантилей
c = normal2.ppf(0.25)
d = normal2.ppf(0.9)
print("0.25 квантиль:", c)
print("0.9 квантиль:", d)

# Построение графиков pdf и cdf
x = np.linspace(0, 20, 100)
pdf = expon.pdf(x, scale=5)
cdf = expon.cdf(x, scale=5)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(x, pdf, label='PDF')
plt.title('PDF')
plt.xlabel('Время ожидания')
plt.ylabel('Вероятность')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(x, cdf, label='CDF', color='r')
plt.title('CDF')
plt.xlabel('Время ожидания')
plt.ylabel('Вероятность')
plt.legend()

plt.show()
# Out:
# Среднее: 5.0
# Дисперсия: 25.0
# 0.25 квантиль: 1.6275512490195916
# 0.9 квантиль: 11.407757827723001

# %% [markdown]
# Для 3 задачи

# %%
# Заданные параметры
mu3 = 161
sigma3 = 4

normal3 = norm(161, 4)

# Посчитаем среднее и дисперсию
mean3, var3 = normal3.stats(moments='mv')

# Расчет квантилей
quantile_25 = norm.ppf(0.25, mu3, sigma3)
quantile_90 = norm.ppf(0.9, mu3, sigma3)

# Построение графиков cdf и pdf
x3 = np.linspace(mu3 - 4*sigma3, mu3 + 4*sigma3, 1000)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(x3, norm.cdf(x3, mean3, sigma3))
plt.title('CDF')
plt.subplot(1, 2, 2)
plt.plot(x3, norm.pdf(x3, mean3, sigma3))
plt.title('PDF')

plt.show()

print("Среднее значение роста: {:.2f}".format(mean3))
print("Дисперсия: {:.2f}".format(var3))
print("25-й квантиль: {:.2f}".format(quantile_25))
print("90-й квантиль: {:.2f}".format(quantile_90))
# Out:
# Среднее значение роста: 161.00
# Дисперсия: 16.00
# 25-й квантиль: 158.30
# 90-й квантиль: 166.13

# %% [markdown]
# Для 4 задачи

# %%
from scipy.stats import poisson

mu4 = 100
sigma4 = 12

normal4 = norm(100, 12)

# Среднее и дисперсия
mean4, var4 = normal4.stats(moments='mv')
print('Среднее значение:', mean4)
print('Дисперсия:', var4)

# Квантили
q_025 = normal4.ppf(0.25)
q_09 = normal4.ppf(0.9)
print('0.25 квантиль:', q_025)
print('0.9 квантиль:', q_09)

# Графики cdf и pdf
x4 = np.arange(70, 130)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(x, norm.cdf(x4, mu4, sigma4))
plt.title('CDF')
plt.subplot(1, 2, 2)
plt.plot(x, norm.pdf(x4, mu4, sigma4))
plt.title('PDF')

plt.show()
# Out:
# Среднее значение: 100.0
# Дисперсия: 144.0
# 0.25 квантиль: 91.90612299764702
# 0.9 квантиль: 115.3786187865352
